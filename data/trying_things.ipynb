# %%
import pandas as pd

# %%
data = pd.read_csv("training.csv")

# %%
data[data['prognosis'] == 'Chronic cholestasis']
# Out:
#       itching  skin_rash  nodal_skin_eruptions  continuous_sneezing  \
# 30          1          0                     0                    0
# 31          0          0                     0                    0
# 32          1          0                     0                    0
# 33          1          0                     0                    0
# 34          1          0                     0                    0
# ...       ...        ...                   ...                  ...
# 4718        1          0                     0                    0
# 4759        1          0                     0                    0
# 4800        1          0                     0                    0
# 4841        1          0                     0                    0
# 4882        1          0                     0                    0
#
#       shivering  chills  joint_pain  stomach_pain  acidity  ulcers_on_tongue  \
# ...

# %%
data[data['prognosis']=='Chronic cholestasis'].iloc[30,:].loc[lambda x : x == 1]
# Out:
# itching              1
# vomiting             1
# yellowish_skin       1
# nausea               1
# loss_of_appetite     1
# abdominal_pain       1
# yellowing_of_eyes    1
# Name: 1260, dtype: object

# %%
data[data['prognosis']=='Chronic cholestasis'].iloc[4882,:].loc[lambda x : x == 1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5964/533547622.py in <module>
# ----> 1 data[data['prognosis']=='Chronic cholestasis'].iloc[4882,:].loc[lambda x : x == 1]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
# ...

# %%
data[data['prognosis']=='Chronic cholestasis'].iloc[4800,:].loc[lambda x : x == 1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5964/2481867938.py in <module>
# ----> 1 data[data['prognosis']=='Chronic cholestasis'].iloc[4800,:].loc[lambda x : x == 1]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
# ...

# %%
data[data['prognosis']=='Bronchial Asthma'].iloc[95,:].loc[lambda x : x == 1]
# Out:
# fatigue           1
# cough             1
# high_fever        1
# breathlessness    1
# family_history    1
# mucoid_sputum     1
# Name: 3904, dtype: object

# %%
data[data['prognosis']=='Bronchial Asthma'].iloc[93,:].loc[lambda x : x == 1]
# Out:
# fatigue           1
# cough             1
# high_fever        1
# breathlessness    1
# family_history    1
# mucoid_sputum     1
# Name: 3822, dtype: object

# %%
data[data['prognosis']=='Bronchial Asthma'].iloc[96,:].loc[lambda x : x == 1]
# Out:
# fatigue           1
# cough             1
# high_fever        1
# breathlessness    1
# family_history    1
# mucoid_sputum     1
# Name: 3945, dtype: object
